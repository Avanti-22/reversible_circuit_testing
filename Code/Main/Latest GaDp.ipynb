# %%
# from google.colab import drive
# drive.mount('/content/drive')

import os
import sys
# The path to the directory saving your .py file or package folder
package_path = 'Code\Main'
# Add the path to system path
if package_path not in sys.path:
    sys.path.insert(0, package_path)

# !python "/content/drive/MyDrive/Dissertation Work/Research Work/Organized/Main/ga_engine.py"

# %%
from experiment_runner import *
from concurrent.futures import ProcessPoolExecutor

input_path = "Benchmarks Used in Base Paper\All Circuits\3_17_13.real"

# Practical max
# fault_models = ["SA-1", "SA-0", "MMGF", "SMGF", "PMGF", "GAF", "CAF", "RGF", "BF", "MBF"]
fault_models = ["SMGF"]

if __name__ == "__main__":
    run_pipeline(input_path, fault_models=fault_models, time_limit_seconds=300.0, verbose=True, skip_minimization= False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 from experiment_runner import *
#       2 from concurrent.futures import ProcessPoolExecutor
#       4 input_path = "Benchmarks Used in Base Paper\All Circuits\3_17_13.real"
#
# File c:\Users\thale\OneDrive\Documents\Avanti\MTech\Dissertation\Code\Main\experiment_runner.py:4, in <module>
#       1 # experiment_runner.py
#       3 from posixpath import basename
# ----> 4 from batch_parsing_functions import *
#       5 from ga_engine import *
#       6 from results_logger import *
#
# File c:\Users\thale\OneDrive\Documents\Avanti\MTech\Dissertation\Code\Main\batch_parsing_functions.py:4, in <module>
#       1 from parser import *
#       3 # =======================PARSE REAL FILE=========================
# ----> 4 def parse_real_file(filepath: str) -> Dict[str, Any]:
# ...
