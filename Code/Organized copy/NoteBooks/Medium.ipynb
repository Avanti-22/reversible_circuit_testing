# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
sys.path.append(project_root)

# %%
import itertools
from typing import Set
from Organized.Utils.circuitParsingUtilityFunctions import *
from Organized.Utils.circuitVectorSimulationUtils import *
from Organized.Utils.SimulatorsfaultCoverageFindingUtilities import *
from Organized.Utils.Ga2 import *
import random
import numpy as np

# %%
def save_results_to_csv(results, output_path):
        resultDf = pd.DataFrame(results)
        resultDf.to_csv(output_path, index=False)
    
    
def run_ga_for_all_files(input_directory , faultModel = "SMGF", population_size=20, max_generations= 20,  output_path = None):
    print("here")
    
    circuits =parse_real_directory(input_directory) 
    # print(circuits)
    results = []   
    
    for circuit in circuits:
        print("here")
        try:
                
            print(circuit["Circuit Name"])
            
            if faultModel =="SMGF":
                
                GAforSMGF = GeneticAlgorithm(circuit, faultModel, population_size, max_generations, time_limit_seconds = 180.0)
                results.append(GAforSMGF.run(verbose=False))
                
            elif faultModel =="MMGF":
                
                GAforMMGF = GeneticAlgorithm(circuit, faultModel, population_size, max_generations, time_limit_seconds = 180.0)
                results.append(GAforMMGF.run(verbose=False))
            
            elif faultModel =="PMGF":
                
                GAforPMGF = GeneticAlgorithm(circuit, faultModel, population_size, max_generations, time_limit_seconds = 180.0)
                results.append(GAforPMGF.run(verbose=False))
            
            elif faultModel =="GAF":
                
                GAforGAF = GeneticAlgorithm(circuit, faultModel, population_size, max_generations, time_limit_seconds = 180.0)
                results.append(GAforGAF.run(verbose=False))
            
            elif faultModel =="CAF":
                
                GAforCAF = GeneticAlgorithm(circuit, faultModel, population_size, max_generations, time_limit_seconds = 180.0)
                results.append(GAforCAF.run(verbose=False))
            
            elif faultModel =="SA-1":
                
                GAforSAF1 = GeneticAlgorithm(circuit, faultModel, population_size, max_generations, time_limit_seconds = 180.0)
                results.append(GAforSAF1.run(verbose=False))
            
            elif faultModel =="SA-0":
                
                GAforSAF0 = GeneticAlgorithm(circuit, faultModel, population_size, max_generations, time_limit_seconds = 180.0)
                results.append(GAforSAF0.run(verbose=False))
            
            elif faultModel =="RGF":
                
                GAforRGF = GeneticAlgorithm(circuit, faultModel, population_size, max_generations, time_limit_seconds = 180.0)
                results.append(GAforRGF.run(verbose=False))
            
            elif faultModel =="BF":
                
                GAforBF = GeneticAlgorithm(circuit, faultModel, population_size, max_generations, time_limit_seconds = 180.0)
                results.append(GAforBF.run(verbose=False))
            
            elif faultModel =="MBF":
                
                GAforMBF = GeneticAlgorithm(circuit, faultModel, population_size, max_generations, time_limit_seconds = 180.0)
                results.append(GAforMBF.run(verbose=False))
    
            
        except Exception as e:
            circuit_name = None
            try:
                circuit_name = circuit.get("Circuit Name") if circuit is not None else None
            except Exception:
                circuit_name = None
            print(f"Error processing circuit {circuit_name}: {e}")
            continue
        print(results)
        print("done for circuit this")
    print("\n\nSaving the results\n\n")
    save_results_to_csv(results, output_path)
    return results
    
# run the code for all the circuits. add the code to record time
# also save the results

# %%
folder_path = r"C:\Users\thale\OneDrive\Documents\Avanti\MTech\Dissertation\Benchmarks Used in Base Paper\Medium"

# %%
results = run_ga_for_all_files(folder_path, faultModel = "PMGF", output_path= "PMGF_medium.csv")

# %%
print(results)

# %%
results = run_ga_for_all_files(folder_path, faultModel = "MMGF", output_path= "MMGF_medium.csv")

# %%
results = run_ga_for_all_files(folder_path, faultModel = "RGF", output_path= "RGF_medium.csv")

# %%
results = run_ga_for_all_files(folder_path, faultModel = "SA-1", output_path= "SA-1_medium.csv")

# %%
results = run_ga_for_all_files(folder_path, faultModel = "SA-0", output_path= "SA-0_medium.csv")

# %%
results = run_ga_for_all_files(folder_path, faultModel = "CAF", output_path= "CAF_medium.csv")

# %%
print(results)

# %%
results = run_ga_for_all_files(folder_path, faultModel = "GAF", output_path= "GAF_medium.csv")

# %%
results = run_ga_for_all_files(folder_path, faultModel = "BF", output_path= "BF_medium.csv")

# %%
results = run_ga_for_all_files(folder_path, faultModel = "MBF", output_path= "MBF_medium.csv")

# %%
results = run_ga_for_all_files(folder_path, faultModel = "SMGF", output_path= "SMGF_medium.csv")
